# %% [markdown]
# # Decision Trees, Random Forests and the Confusion Matrix for Evaluation
# ## Data Mining Catawba College
# ## Group Members:
# ## 1. Christian Kernell
# ## 2.

# %% [markdown]
# # Directions: Open in COLAB.  Carefully study the documentation and execute the code.  Answer the questions throughout the lab and at the end of the lab. They are labeled "Question 1" etc. Save your work and turn in the .ipynb file.
#
# For this project we will be exploring publicly available data from [LendingClub.com](www.lendingclub.com). Lending Club connects people who need money (borrowers) with people who have money (investors). Hopefully, as an investor you would want to invest in people who showed a profile of having a high probability of paying you back. We will try to create a model that will help predict this.
#
# ### Research Goal:  Develop a predictive model using decision trees to determine applicants that are most likely to be able to pay back their loans.
#
# Lending club had a [very interesting year in 2016](https://en.wikipedia.org/wiki/Lending_Club#2016), so let's check out some of their data and keep the context in mind. This data is from before they even went public.
#
# We will use lending data from 2007-2010 and be trying to classify and predict whether or not the borrower paid back their loan in full. You can download the original data from [here](https://www.lendingclub.com/info/download-data.action) but we are using a csv provided as it has been cleaned of NA values or NULL values.
#
# ### Data Understanding - Here are what the columns represent:
# * int.rate: The interest rate of the loan, as a proportion (a rate of 11% would be stored as 0.11). Borrowers judged by LendingClub.com to be more risky are assigned higher interest rates.
# * installment: The monthly installments owed by the borrower if the loan is funded.
# * log.annual.inc: The natural log of the self-reported annual income of the borrower.
# * dti: The debt-to-income ratio of the borrower (amount of debt divided by annual income).
# * fico: The FICO credit score of the borrower.
# * days.with.cr.line: The number of days the borrower has had a credit line.
# * revol.bal: The borrower's revolving balance (amount unpaid at the end of the credit card billing cycle).
# * revol.util: The borrower's revolving line utilization rate (the amount of the credit line used relative to total credit available).
# * inq.last.6mths: The borrower's number of inquiries by creditors in the last 6 months.
# * pub.rec: The borrower's number of derogatory public records (bankruptcy filings, tax liens, or judgments).
# * fully.paid - yes or 1 if the loan was paid back in full (yes is good), no or 0  means it was not paid back in full

# %% [markdown]
# # 1.  Import Libraries
#
# **Import the usual libraries for pandas and plotting. You can import sklearn later on.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2. Get the Data
#
# ** Use pandas to read loan_data.csv as a dataframe called loans.  Remember this file has the NULL values removed. **

# %%
df = pd.read_csv('https://raw.githubusercontent.com/catawba-data-mining/CIS-3902-Data-Mining/main/loan_data_prep.csv')

# %% [markdown]
# ## 3. Look at the first few records, the attributes, and attributes types.
# ** Check out the info(), head(), and describe() methods on loans.**

# %%
df.head()
# Out:
#    credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1    0.1189       829.10       11.350407  19.48   737
# 1              1    0.1071       228.22       11.082143  14.29   707
# 2              1    0.1357       366.86       10.373491  11.63   682
# 3              1    0.1008       162.34       11.350407   8.10   712
# 4              1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  fully.paid
# 0        5639.958333      28854        52.1               0           1
# 1        2760.000000      33623        76.7               0           1
# 2        4710.000000       3511        25.6               1           1
# 3        2699.958333      33667        73.2               1           1
# 4        4066.000000       4740        39.5               0           1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   int.rate           9578 non-null   float64
#  2   installment        9578 non-null   float64
#  3   log.annual.inc     9578 non-null   float64
#  4   dti                9578 non-null   float64
#  5   fico               9578 non-null   int64
#  6   days.with.cr.line  9578 non-null   float64
#  7   revol.bal          9578 non-null   int64
#  8   revol.util         9578 non-null   float64
#  9   inq.last.6mths     9578 non-null   int64
#  10  fully.paid         9578 non-null   int64
# dtypes: float64(6), int64(5)
# memory usage: 823.2 KB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# min     612.000000         178.958333  0.000000e+00     0.000000
# 25%     682.000000        2820.000000  3.187000e+03    22.600000
# 50%     707.000000        4139.958333  8.596000e+03    46.300000
# 75%     737.000000        5730.000000  1.824950e+04    70.900000
# max     827.000000       17639.958330  1.207359e+06   119.000000
#
#        inq.last.6mths   fully.paid
# count     9578.000000  9578.000000
# mean         1.577469     0.839946
# std          2.200245     0.366676
# min          0.000000     0.000000
# 25%          0.000000     1.000000
# 50%          1.000000     1.000000
# 75%          2.000000     1.000000
# max         33.000000     1.000000

# %% [markdown]
# ##  4.  Exploratory Data Analysis:  Visualization
#
# Let's do some data visualization!

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df['credit.policy']==1]['fico'],color='blue',bins=30,alpha=0.5,edgecolor='blue')
plt.hist(df[df['credit.policy']==0]['fico'],color='red',bins=30,alpha=0.5,edgecolor='red')
plt.legend(['credit.policy=1','credit.policy=0'])
plt.xlabel("FICO")
# Out:
# Text(0.5, 0, 'FICO')

# %% [markdown]
# ## QUESTION 1:  (open up the markdown cell and key in your answer).  What does the above chart show about the relationship of FICO score and Credit Policy?<br>The chart shows us that people that meet the credit policy have higher FICO scores and people that don't meet the credit policy have lower FICO scores.

# %% [markdown]
# ** Create a histogram -  select by the not.fully.paid column.**<br>
# ** fully paid = 1 is good **

# %%
plt.figure(figsize=(10,6))
plt.hist(df[df['fully.paid']==1]['fico'],color='red',bins=30,alpha=0.5,edgecolor='red')
plt.hist(df[df['fully.paid']==0]['fico'],color='blue',bins=30,alpha=0.5,edgecolor='blue')
plt.legend(['fully.paid=1','fully.paid=0'])
plt.xlabel("FICO")
# Out:
# Text(0.5, 0, 'FICO')

# %% [markdown]
# ## QUESTION 2: What does the above chart show about the relationship of FICO score and Not Fully Paid?<br> This chart shows that people that have fully paid their loans tend to have a higher FICO score and those who have not fully paid their loan tend to have a somewhat even distribution across FICO scores.

# %% [markdown]
# ** Let's see the trend between FICO score and interest rate.**

# %%
sns.jointplot(x='fico', y='int.rate', data=df, color='purple', size=8, ratio=3, space=0.4)

# %% [markdown]
# ## QUESTION 3: In the chart above, do you see a trend between FICO score and Interest Rate?<br>As the FICO score increases, the interest rate tends to decrease. There is an inverse relationship.

# %% [markdown]
# ** Create the following lmplots to see if the trend differed between not.fully.paid and credit.policy.**

# %%
sns.lmplot(x='fico', y='int.rate', hue='credit.policy', col='fully.paid', data=df, height=8)

# %% [markdown]
# ## QUESTION 4: What do the above two charts show regarding the trend between FICO score and Interest Rate, and how it may or may not differ depending on the "Not Fully Paid" Attribute? <br>The first chart shows that people who meet the credit policy tend to have a lower interest rate across different FICO scores compared to those who do not meet the credit policy. The second shows us, again, the inverse relationship between FICO and interest rate.

# %% [markdown]
# ## 5.  Data Preparation
#
# Let's get our data ready for decision trees and random forest modeling.  <br><br>
# A decision tree is a flowchart-like tree structure where an internal node represents feature(or attribute), the branch represents a decision rule, and each leaf node represents the outcome. The topmost node in a decision tree is known as the root node. It learns to partition on the basis of the attribute value. It partitions the tree in recursively manner call recursive partitioning. This flowchart-like structure helps you in decision making. It's visualization like a flowchart diagram which easily mimics the human level thinking. That is why decision trees are easy to understand and interpret.<br><br>
# Random Forests are like a collection of decision trees taken from random samples from the data:
# It works in four steps:<br>   Select random samples from a given dataset.<br>
#     Construct a decision tree for each sample and get a prediction result from each decision tree.<br>
#     Perform a vote for each predicted result.<br>
#     Select the prediction result with the most votes as the final prediction.<br><br>
# Random Forests almost always outperform Decision Trees.
#
#
# ** Let's start by checking loans.info() again.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   int.rate           9578 non-null   float64
#  2   installment        9578 non-null   float64
#  3   log.annual.inc     9578 non-null   float64
#  4   dti                9578 non-null   float64
#  5   fico               9578 non-null   int64
#  6   days.with.cr.line  9578 non-null   float64
#  7   revol.bal          9578 non-null   int64
#  8   revol.util         9578 non-null   float64
#  9   inq.last.6mths     9578 non-null   int64
#  10  fully.paid         9578 non-null   int64
# dtypes: float64(6), int64(5)
# memory usage: 823.2 KB

# %% [markdown]
# ### We are using Python's scikit-learn to make our modeling process easier with this powerful library.<br><br>
# <p>It is important to understand how to prepare data for each type of modeling.</p>
# <p> We have a target variable, Not Fully Paid, to predict if we are going to get paid back or not. Since we have a target variable this is Supervised learning.</p><p>We have already removed nulls, this is generally important although just simply removing them isn't always the best practice because you might remove too much of the data!  More on this later.  </p>
# <p>Decision trees handle numerical values and categorical values, although scikit-learn requires us to change the categorical variables to "dummy" variables.  This means if we have a Cateorical Variable Direction with North, South, East and West as the possible categories, this will change to three variables (not four) North, South, and East.  If the direction for a particular record was "North", then North will have "1" and the rest will have "0". If the direction is "West" then the three will have 0 . . . all 0's mean the last category or West.</p>
# <p>The original data set has a categorical feature "Loan Purpose" which has been removed from the data due to its lack of importance in the prediction</p>
# <p> Numerical features for decision trees do not have to be "normalized" meaning if you have numerical variables in different ranges, you do not have to convert them to a similar scale.</p>

# %% [markdown]
# ### Train and Test.  We train our model on the training data, and test the accuracy of the model we have built on test.
#
# Now its time to split our data into a training set and a testing set!

# %%
# our target is the fully paid variable
# the train set will be trained on the target so we can learn what it means
# again this is supervised learning
# we will test our model on the test set
X = df.drop('fully.paid',axis=1)
y = df['fully.paid']

# %%
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split

# %%
# train will have 70% of the data, test will have 30%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=101)

# %% [markdown]
# ## 6.  Modeling:  Training a Decision Tree Model
#
# Let's start by training a single decision tree first!

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dTree = DecisionTreeClassifier()

# %%
dTree.fit(X_train,y_train)

# %%
# this may take a few minutes to run
tree.plot_tree(dTree)
# Out:
# [Text(0.37030819961213357, 0.9821428571428571, 'x[0] <= 0.5\ngini = 0.272\nsamples = 6704\nvalue = [1090, 5614]'),
#  Text(0.16491765668677358, 0.9464285714285714, 'x[2] <= 349.935\ngini = 0.408\nsamples = 1317\nvalue = [376, 941]'),
#  Text(0.11560017287038399, 0.9107142857142857, 'x[9] <= 6.5\ngini = 0.378\nsamples = 943\nvalue = [239, 704]'),
#  Text(0.06384710166249816, 0.875, 'x[1] <= 0.084\ngini = 0.36\nsamples = 815\nvalue = [192, 623]'),
#  Text(0.0626701118140356, 0.8392857142857143, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.06502409151096072, 0.8392857142857143, 'x[8] <= 50.95\ngini = 0.368\nsamples = 789\nvalue = [192, 597]'),
#  Text(0.01742956451375607, 0.8035714285714286, 'x[8] <= 47.35\ngini = 0.324\nsamples = 344\nvalue = [70, 274]'),
#  Text(0.016252574665293514, 0.7678571428571429, 'x[3] <= 9.818\ngini = 0.343\nsamples = 319\nvalue = [70, 249]'),
#  Text(0.006473444166544063, 0.7321428571428571, 'x[2] <= 78.13\ngini = 0.464\nsamples = 41\nvalue = [15, 26]'),
#  Text(0.003530969545387671, 0.6964285714285714, 'x[8] <= 12.95\ngini = 0.219\nsamples = 16\nvalue = [2, 14]'),
#  Text(0.002353979696925114, 0.6607142857142857, 'x[4] <= 4.435\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.001176989848462557, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.003530969545387671, 0.625, 'x[3] <= 9.19\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.002353979696925114, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.004707959393850228, 0.5892857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.004707959393850228, 0.6607142857142857, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.009415918787700456, 0.6964285714285714, 'x[8] <= 19.65\ngini = 0.499\nsamples = 25\nvalue = [13, 12]'),
#  Text(0.007061939090775342, 0.6607142857142857, 'x[3] <= 8.883\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.005884949242312785, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.008238928939237899, 0.625, 'x[4] <= 14.865\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.007061939090775342, 0.5892857142857143, 'x[1] <= 0.102\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.005884949242312785, 0.5535714285714286, 'x[6] <= 855.021\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.004707959393850228, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.007061939090775342, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.008238928939237899, 0.5535714285714286, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.009415918787700456, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.01176989848462557, 0.6607142857142857, 'x[6] <= 3285.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.010592908636163013, 0.625, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.012946888333088127, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.02603170516404296, 0.7321428571428571, 'x[3] <= 10.444\ngini = 0.317\nsamples = 278\nvalue = [55, 223]'),
#  Text(0.02059732234809475, 0.6964285714285714, 'x[5] <= 734.5\ngini = 0.126\nsamples = 74\nvalue = [5, 69]'),
#  Text(0.017654847726938355, 0.6607142857142857, 'x[6] <= 7680.0\ngini = 0.081\nsamples = 71\nvalue = [3, 68]'),
#  Text(0.01530086803001324, 0.625, 'x[7] <= 153.0\ngini = 0.056\nsamples = 69\nvalue = [2, 67]'),
#  Text(0.014123878181550684, 0.5892857142857143, 'x[8] <= 39.8\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.012946888333088127, 0.5535714285714286, 'x[3] <= 9.878\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.01176989848462557, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.014123878181550684, 0.5178571428571429, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.01530086803001324, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.016477857878475798, 0.5892857142857143, 'gini = 0.0\nsamples = 56\nvalue = [0, 56]'),
#  Text(0.02000882742386347, 0.625, 'x[5] <= 674.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.01883183757540091, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.021185817272326025, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.02353979696925114, 0.6607142857142857, 'x[9] <= 2.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.022362807120788582, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.024716786817713696, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.031466087979991175, 0.6964285714285714, 'x[4] <= 0.285\ngini = 0.37\nsamples = 204\nvalue = [50, 154]'),
#  Text(0.030289098131528615, 0.6607142857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.03264307782845373, 0.6607142857142857, 'x[8] <= 1.7\ngini = 0.358\nsamples = 201\nvalue = [47, 154]'),
#  Text(0.02707076651463881, 0.625, 'x[4] <= 6.3\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.024716786817713696, 0.5892857142857143, 'x[6] <= 1298.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.02353979696925114, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025893776666176253, 0.5535714285714286, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.029424746211563924, 0.5892857142857143, 'x[7] <= 20.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.028247756363101367, 0.5535714285714286, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.03060173606002648, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03821538914226865, 0.625, 'x[8] <= 14.5\ngini = 0.339\nsamples = 185\nvalue = [40, 145]'),
#  Text(0.034132705605414156, 0.5892857142857143, 'x[2] <= 253.12\ngini = 0.111\nsamples = 34\nvalue = [2, 32]'),
#  Text(0.032955715756951595, 0.5535714285714286, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.03530969545387671, 0.5535714285714286, 'x[3] <= 10.83\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.034132705605414156, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.03648668530233927, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.042298072679123146, 0.5892857142857143, 'x[8] <= 14.85\ngini = 0.377\nsamples = 151\nvalue = [38, 113]'),
#  Text(0.041121082830660585, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0434750625275857, 0.5535714285714286, 'x[1] <= 0.19\ngini = 0.366\nsamples = 149\nvalue = [36, 113]'),
#  Text(0.038840664999264383, 0.5178571428571429, 'x[6] <= 5790.0\ngini = 0.352\nsamples = 145\nvalue = [33, 112]'),
#  Text(0.03310283948800941, 0.48214285714285715, 'x[6] <= 4859.521\ngini = 0.39\nsamples = 113\nvalue = [30, 83]'),
#  Text(0.028689127556274827, 0.44642857142857145, 'x[2] <= 338.055\ngini = 0.334\nsamples = 99\nvalue = [21, 78]'),
#  Text(0.025746652935118436, 0.4107142857142857, 'x[8] <= 34.85\ngini = 0.307\nsamples = 95\nvalue = [18, 77]'),
#  Text(0.023392673238193322, 0.375, 'x[8] <= 33.9\ngini = 0.387\nsamples = 61\nvalue = [16, 45]'),
#  Text(0.022215683389730765, 0.3392857142857143, 'x[3] <= 11.112\ngini = 0.332\nsamples = 57\nvalue = [12, 45]'),
#  Text(0.01986170369280565, 0.30357142857142855, 'x[5] <= 657.0\ngini = 0.424\nsamples = 36\nvalue = [11, 25]'),
#  Text(0.018684713844343094, 0.26785714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.021038693541268208, 0.26785714285714285, 'x[3] <= 11.09\ngini = 0.389\nsamples = 34\nvalue = [9, 25]'),
#  Text(0.01986170369280565, 0.23214285714285715, 'x[4] <= 2.27\ngini = 0.342\nsamples = 32\nvalue = [7, 25]'),
#  Text(0.017507723995880537, 0.19642857142857142, 'x[4] <= 0.77\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.01633073414741798, 0.16071428571428573, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.018684713844343094, 0.16071428571428573, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.022215683389730765, 0.19642857142857142, 'x[3] <= 10.456\ngini = 0.285\nsamples = 29\nvalue = [5, 24]'),
#  Text(0.021038693541268208, 0.16071428571428573, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.023392673238193322, 0.16071428571428573, 'x[8] <= 33.25\ngini = 0.245\nsamples = 28\nvalue = [4, 24]'),
#  Text(0.022215683389730765, 0.125, 'x[3] <= 10.88\ngini = 0.198\nsamples = 27\nvalue = [3, 24]'),
#  Text(0.018684713844343094, 0.08928571428571429, 'x[6] <= 4289.958\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.017507723995880537, 0.05357142857142857, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.01986170369280565, 0.05357142857142857, 'x[4] <= 19.27\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.018684713844343094, 0.017857142857142856, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.021038693541268208, 0.017857142857142856, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.025746652935118436, 0.08928571428571429, 'x[4] <= 10.53\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.02456966308665588, 0.05357142857142857, 'x[5] <= 697.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.023392673238193322, 0.017857142857142856, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.025746652935118436, 0.017857142857142856, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.026923642783580993, 0.05357142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.02456966308665588, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.022215683389730765, 0.23214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.02456966308665588, 0.30357142857142855, 'x[5] <= 724.5\ngini = 0.091\nsamples = 21\nvalue = [1, 20]'),
#  Text(0.023392673238193322, 0.26785714285714285, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.025746652935118436, 0.26785714285714285, 'x[2] <= 263.355\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.02456966308665588, 0.23214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.026923642783580993, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.02456966308665588, 0.3392857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.02810063263204355, 0.375, 'x[2] <= 51.54\ngini = 0.111\nsamples = 34\nvalue = [2, 32]'),
#  Text(0.026923642783580993, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.029277622480506107, 0.3392857142857143, 'x[3] <= 11.537\ngini = 0.059\nsamples = 33\nvalue = [1, 32]'),
#  Text(0.02810063263204355, 0.30357142857142855, 'gini = 0.0\nsamples = 31\nvalue = [0, 31]'),
#  Text(0.030454612328968664, 0.30357142857142855, 'x[1] <= 0.127\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.029277622480506107, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03163160217743122, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03163160217743122, 0.4107142857142857, 'x[4] <= 4.935\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.030454612328968664, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03280859202589378, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.037516551419744006, 0.44642857142857145, 'x[1] <= 0.153\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.036339561571281445, 0.4107142857142857, 'x[5] <= 689.5\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.03516257172281889, 0.375, 'x[4] <= 11.26\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.03398558187435633, 0.3392857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.036339561571281445, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.037516551419744006, 0.375, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.03869354126820656, 0.4107142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04457849051051935, 0.48214285714285715, 'x[1] <= 0.096\ngini = 0.17\nsamples = 32\nvalue = [3, 29]'),
#  Text(0.042224510813594233, 0.44642857142857145, 'x[8] <= 26.8\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.04104752096513167, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04340150066205679, 0.4107142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.04693247020744446, 0.44642857142857145, 'x[1] <= 0.157\ngini = 0.067\nsamples = 29\nvalue = [1, 28]'),
#  Text(0.0457554803589819, 0.4107142857142857, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.048109460055907015, 0.4107142857142857, 'x[9] <= 5.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04693247020744446, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.049286449904369575, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.048109460055907015, 0.5178571428571429, 'x[3] <= 11.363\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.04693247020744446, 0.48214285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.049286449904369575, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.018606554362218627, 0.7678571428571429, 'gini = 0.0\nsamples = 25\nvalue = [0, 25]'),
#  Text(0.11261861850816536, 0.8035714285714286, 'x[6] <= 5342.0\ngini = 0.398\nsamples = 445\nvalue = [122, 323]'),
#  Text(0.09782808592025893, 0.7678571428571429, 'x[7] <= 7884.0\ngini = 0.372\nsamples = 356\nvalue = [88, 268]'),
#  Text(0.08420994556421951, 0.7321428571428571, 'x[5] <= 712.0\ngini = 0.426\nsamples = 179\nvalue = [55, 124]'),
#  Text(0.08303295571575695, 0.6964285714285714, 'x[7] <= 7535.0\ngini = 0.413\nsamples = 175\nvalue = [51, 124]'),
#  Text(0.07617331175518612, 0.6607142857142857, 'x[1] <= 0.164\ngini = 0.4\nsamples = 170\nvalue = [47, 123]'),
#  Text(0.0659849933794321, 0.625, 'x[4] <= 20.94\ngini = 0.377\nsamples = 155\nvalue = [39, 116]'),
#  Text(0.06480800353096955, 0.5892857142857143, 'x[4] <= 14.675\ngini = 0.405\nsamples = 138\nvalue = [39, 99]'),
#  Text(0.05443578049139326, 0.5535714285714286, 'x[4] <= 0.975\ngini = 0.355\nsamples = 104\nvalue = [24, 80]'),
#  Text(0.0532587906429307, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.055612770339855816, 0.5178571428571429, 'x[8] <= 53.35\ngini = 0.338\nsamples = 102\nvalue = [22, 80]'),
#  Text(0.05164042960129469, 0.48214285714285715, 'x[7] <= 1722.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.05046343975283213, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05281741944975724, 0.44642857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.05958511107841695, 0.48214285714285715, 'x[6] <= 390.5\ngini = 0.315\nsamples = 97\nvalue = [19, 78]'),
#  Text(0.05517139914668236, 0.44642857142857145, 'x[8] <= 71.75\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.0539944092982198, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.05634838899514492, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06399882301015154, 0.44642857142857145, 'x[6] <= 2805.042\ngini = 0.29\nsamples = 91\nvalue = [16, 75]'),
#  Text(0.05870236869207003, 0.4107142857142857, 'x[2] <= 165.555\ngini = 0.191\nsamples = 56\nvalue = [6, 50]'),
#  Text(0.05634838899514492, 0.375, 'x[6] <= 735.0\ngini = 0.057\nsamples = 34\nvalue = [1, 33]'),
#  Text(0.05517139914668236, 0.3392857142857143, 'x[6] <= 690.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.0539944092982198, 0.30357142857142855, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.05634838899514492, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05752537884360747, 0.3392857142857143, 'gini = 0.0\nsamples = 26\nvalue = [0, 26]'),
#  Text(0.061056348388995145, 0.375, 'x[2] <= 167.665\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.059879358540532585, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0622333382374577, 0.3392857142857143, 'x[1] <= 0.13\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.061056348388995145, 0.30357142857142855, 'x[1] <= 0.128\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.059879358540532585, 0.26785714285714285, 'x[3] <= 10.582\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.05870236869207003, 0.23214285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.061056348388995145, 0.23214285714285715, 'x[3] <= 10.847\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.059879358540532585, 0.19642857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0622333382374577, 0.19642857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0622333382374577, 0.26785714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06341032808592026, 0.30357142857142855, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.06929527732823304, 0.4107142857142857, 'x[6] <= 2955.0\ngini = 0.408\nsamples = 35\nvalue = [10, 25]'),
#  Text(0.06811828747977049, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.07047226717669561, 0.375, 'x[9] <= 3.5\ngini = 0.312\nsamples = 31\nvalue = [6, 25]'),
#  Text(0.06694129763130793, 0.3392857142857143, 'x[7] <= 5449.5\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.06576430778284538, 0.30357142857142855, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.06811828747977049, 0.30357142857142855, 'x[4] <= 8.53\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.06694129763130793, 0.26785714285714285, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.06929527732823304, 0.26785714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07400323672208327, 0.3392857142857143, 'x[5] <= 679.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.07282624687362071, 0.30357142857142855, 'x[5] <= 644.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.07164925702515816, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07400323672208327, 0.26785714285714285, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.07518022657054584, 0.30357142857142855, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07518022657054584, 0.5535714285714286, 'x[7] <= 1443.0\ngini = 0.493\nsamples = 34\nvalue = [15, 19]'),
#  Text(0.07282624687362071, 0.5178571428571429, 'x[5] <= 647.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.07164925702515816, 0.48214285714285715, 'x[6] <= 3434.479\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07047226717669561, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07282624687362071, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07400323672208327, 0.48214285714285715, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.07753420626747094, 0.5178571428571429, 'x[5] <= 644.5\ngini = 0.435\nsamples = 25\nvalue = [8, 17]'),
#  Text(0.07635721641900839, 0.48214285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0787111961159335, 0.48214285714285715, 'x[9] <= 2.5\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.07753420626747094, 0.44642857142857145, 'x[4] <= 18.44\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.07635721641900839, 0.4107142857142857, 'x[7] <= 5131.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.07518022657054584, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.07753420626747094, 0.375, 'x[4] <= 17.255\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.07635721641900839, 0.3392857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0787111961159335, 0.3392857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0787111961159335, 0.4107142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07988818596439606, 0.44642857142857145, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.06716198322789466, 0.5892857142857143, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.08636163013094011, 0.625, 'x[5] <= 669.5\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.08341915550978372, 0.5892857142857143, 'x[9] <= 1.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.08106517581285862, 0.5535714285714286, 'x[1] <= 0.164\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07988818596439606, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08224216566132117, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08577313520670884, 0.5535714285714286, 'x[8] <= 68.7\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.08459614535824629, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0869501250551714, 0.5178571428571429, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.08930410475209652, 0.5892857142857143, 'x[1] <= 0.167\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.08812711490363395, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09048109460055907, 0.5535714285714286, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08989259967632779, 0.6607142857142857, 'x[1] <= 0.118\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.08871560982786524, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09106958952479034, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.08538693541268207, 0.6964285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.11144622627629837, 0.7321428571428571, 'x[9] <= 5.5\ngini = 0.303\nsamples = 177\nvalue = [33, 144]'),
#  Text(0.1041636015889363, 0.6964285714285714, 'x[3] <= 11.382\ngini = 0.272\nsamples = 166\nvalue = [27, 139]'),
#  Text(0.09872002353979697, 0.6607142857142857, 'x[8] <= 83.55\ngini = 0.226\nsamples = 131\nvalue = [17, 114]'),
#  Text(0.09636604384287185, 0.625, 'x[8] <= 82.85\ngini = 0.292\nsamples = 90\nvalue = [16, 74]'),
#  Text(0.0951890539944093, 0.5892857142857143, 'x[1] <= 0.167\ngini = 0.254\nsamples = 87\nvalue = [13, 74]'),
#  Text(0.09283507429748418, 0.5535714285714286, 'x[4] <= 19.83\ngini = 0.214\nsamples = 82\nvalue = [10, 72]'),
#  Text(0.09165808444902163, 0.5178571428571429, 'x[4] <= 19.265\ngini = 0.298\nsamples = 55\nvalue = [10, 45]'),
#  Text(0.09048109460055907, 0.48214285714285715, 'x[7] <= 18822.5\ngini = 0.256\nsamples = 53\nvalue = [8, 45]'),
#  Text(0.08930410475209652, 0.44642857142857145, 'x[8] <= 64.2\ngini = 0.367\nsamples = 33\nvalue = [8, 25]'),
#  Text(0.08812711490363395, 0.4107142857142857, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.09048109460055907, 0.4107142857142857, 'x[8] <= 73.15\ngini = 0.48\nsamples = 20\nvalue = [8, 12]'),
#  Text(0.0869501250551714, 0.375, 'x[5] <= 689.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.08577313520670884, 0.3392857142857143, 'x[4] <= 17.19\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.08459614535824629, 0.30357142857142855, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.0869501250551714, 0.30357142857142855, 'x[8] <= 66.25\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.08577313520670884, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08812711490363395, 0.26785714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08812711490363395, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09401206414594675, 0.375, 'x[5] <= 649.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.09283507429748418, 0.3392857142857143, 'x[7] <= 11968.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.09165808444902163, 0.30357142857142855, 'x[3] <= 10.436\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09048109460055907, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09283507429748418, 0.26785714285714285, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09401206414594675, 0.30357142857142855, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.0951890539944093, 0.3392857142857143, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.09165808444902163, 0.44642857142857145, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.09283507429748418, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09401206414594675, 0.5178571428571429, 'gini = 0.0\nsamples = 27\nvalue = [0, 27]'),
#  Text(0.09754303369133441, 0.5535714285714286, 'x[4] <= 27.415\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.09636604384287185, 0.5178571428571429, 'x[4] <= 17.87\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0951890539944093, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09754303369133441, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.09872002353979697, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09754303369133441, 0.5892857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10107400323672208, 0.625, 'x[5] <= 709.5\ngini = 0.048\nsamples = 41\nvalue = [1, 40]'),
#  Text(0.09989701338825953, 0.5892857142857143, 'gini = 0.0\nsamples = 40\nvalue = [0, 40]'),
#  Text(0.10225099308518464, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10960717963807562, 0.6607142857142857, 'x[3] <= 11.398\ngini = 0.408\nsamples = 35\nvalue = [10, 25]'),
#  Text(0.10578196263057231, 0.625, 'x[6] <= 2459.979\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.10460497278210976, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10695895247903486, 0.5892857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.11343239664557893, 0.625, 'x[8] <= 95.55\ngini = 0.32\nsamples = 30\nvalue = [6, 24]'),
#  Text(0.10931293217595998, 0.5892857142857143, 'x[7] <= 13012.0\ngini = 0.211\nsamples = 25\nvalue = [3, 22]'),
#  Text(0.10813594232749743, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11048992202442254, 0.5535714285714286, 'x[4] <= 26.725\ngini = 0.153\nsamples = 24\nvalue = [2, 22]'),
#  Text(0.10813594232749743, 0.5178571428571429, 'x[9] <= 4.5\ngini = 0.087\nsamples = 22\nvalue = [1, 21]'),
#  Text(0.10695895247903486, 0.48214285714285715, 'gini = 0.0\nsamples = 19\nvalue = [0, 19]'),
#  Text(0.10931293217595998, 0.48214285714285715, 'x[5] <= 689.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10813594232749743, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11048992202442254, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11284390172134766, 0.5178571428571429, 'x[8] <= 88.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.11166691187288509, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11402089156981021, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11755186111519789, 0.5892857142857143, 'x[2] <= 262.85\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.11637487126673532, 0.5535714285714286, 'x[5] <= 667.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11519788141827277, 0.5178571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11755186111519789, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.11872885096366044, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.11872885096366044, 0.6964285714285714, 'x[5] <= 669.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(0.11755186111519789, 0.6607142857142857, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.119905840812123, 0.6607142857142857, 'x[7] <= 21280.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.11872885096366044, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.12108283066058555, 0.625, 'x[2] <= 184.13\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.119905840812123, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12225982050904811, 0.5892857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1274091510960718, 0.7678571428571429, 'x[6] <= 5579.5\ngini = 0.472\nsamples = 89\nvalue = [34, 55]'),
#  Text(0.12623216124760925, 0.7321428571428571, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.12858614094453436, 0.7321428571428571, 'x[8] <= 57.15\ngini = 0.442\nsamples = 82\nvalue = [27, 55]'),
#  Text(0.12461380020597322, 0.6964285714285714, 'x[5] <= 647.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.12343681035751067, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12579079005443577, 0.6607142857142857, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.13255848168309547, 0.6964285714285714, 'x[8] <= 80.25\ngini = 0.403\nsamples = 75\nvalue = [21, 54]'),
#  Text(0.12814476975136088, 0.6607142857142857, 'x[2] <= 137.93\ngini = 0.234\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.12579079005443577, 0.625, 'x[8] <= 69.3\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.12461380020597322, 0.5892857142857143, 'x[2] <= 86.445\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.12343681035751067, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12579079005443577, 0.5535714285714286, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.12696777990289834, 0.5892857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.13049874944828602, 0.625, 'x[8] <= 60.3\ngini = 0.071\nsamples = 27\nvalue = [1, 26]'),
#  Text(0.12932175959982345, 0.5892857142857143, 'x[4] <= 22.995\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.12814476975136088, 0.5535714285714286, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.13049874944828602, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13167573929674856, 0.5892857142857143, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.13697219361483007, 0.6607142857142857, 'x[2] <= 121.115\ngini = 0.488\nsamples = 38\nvalue = [16, 22]'),
#  Text(0.13579520376636753, 0.625, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.13814918346329264, 0.625, 'x[4] <= 17.185\ngini = 0.5\nsamples = 32\nvalue = [16, 16]'),
#  Text(0.1340297189936737, 0.5892857142857143, 'x[3] <= 11.67\ngini = 0.355\nsamples = 13\nvalue = [3, 10]'),
#  Text(0.13285272914521112, 0.5535714285714286, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.13520670884213623, 0.5535714285714286, 'x[1] <= 0.133\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1340297189936737, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1363836986905988, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14226864793291158, 0.5892857142857143, 'x[9] <= 0.5\ngini = 0.432\nsamples = 19\nvalue = [13, 6]'),
#  Text(0.13991466823598647, 0.5535714285714286, 'x[4] <= 25.85\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.1387376783875239, 0.5178571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.141091658084449, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1446226276298367, 0.5535714285714286, 'x[6] <= 5999.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.14344563778137415, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14579961747829925, 0.5178571428571429, 'x[8] <= 83.75\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.1446226276298367, 0.48214285714285715, 'x[6] <= 7094.479\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.14344563778137415, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14579961747829925, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1469766073267618, 0.48214285714285715, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.16735324407826982, 0.875, 'x[1] <= 0.16\ngini = 0.465\nsamples = 128\nvalue = [47, 81]'),
#  Text(0.16183610416360159, 0.8392857142857143, 'x[1] <= 0.153\ngini = 0.496\nsamples = 94\nvalue = [43, 51]'),
#  Text(0.16065911431513905, 0.8035714285714286, 'x[6] <= 6373.979\ngini = 0.489\nsamples = 89\nvalue = [38, 51]'),
#  Text(0.15492128880388406, 0.7678571428571429, 'x[6] <= 1125.021\ngini = 0.47\nsamples = 77\nvalue = [29, 48]'),
#  Text(0.1469766073267618, 0.7321428571428571, 'x[8] <= 21.55\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.14579961747829925, 0.6964285714285714, 'x[4] <= 1.905\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1446226276298367, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1469766073267618, 0.6607142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14815359717522436, 0.6964285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.16286597028100633, 0.7321428571428571, 'x[2] <= 259.77\ngini = 0.451\nsamples = 70\nvalue = [24, 46]'),
#  Text(0.1552155362659997, 0.6964285714285714, 'x[2] <= 171.59\ngini = 0.486\nsamples = 53\nvalue = [22, 31]'),
#  Text(0.14933058702368693, 0.6607142857142857, 'x[7] <= 38.5\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
#  Text(0.14815359717522436, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15050757687214947, 0.625, 'x[8] <= 29.8\ngini = 0.35\nsamples = 31\nvalue = [7, 24]'),
#  Text(0.14933058702368693, 0.5892857142857143, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.15168456672061204, 0.5892857142857143, 'x[8] <= 40.65\ngini = 0.434\nsamples = 22\nvalue = [7, 15]'),
#  Text(0.15050757687214947, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1528615565690746, 0.5535714285714286, 'x[1] <= 0.136\ngini = 0.375\nsamples = 20\nvalue = [5, 15]'),
#  Text(0.15050757687214947, 0.5178571428571429, 'x[4] <= 9.135\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.14933058702368693, 0.48214285714285715, 'x[5] <= 664.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.14815359717522436, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15050757687214947, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15168456672061204, 0.48214285714285715, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.1552155362659997, 0.5178571428571429, 'x[5] <= 644.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.15403854641753714, 0.48214285714285715, 'x[8] <= 52.75\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.1528615565690746, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1552155362659997, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15639252611446225, 0.48214285714285715, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1611004855083125, 0.6607142857142857, 'x[5] <= 694.5\ngini = 0.465\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.15874650581138738, 0.625, 'x[8] <= 36.85\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.15756951596292482, 0.5892857142857143, 'x[5] <= 674.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.15639252611446225, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15874650581138738, 0.5535714285714286, 'x[9] <= 8.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.15756951596292482, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15992349565984992, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15992349565984992, 0.5892857142857143, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1634544652052376, 0.625, 'x[7] <= 18114.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.16227747535677506, 0.5892857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16463145505370017, 0.5892857142857143, 'x[7] <= 33065.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1634544652052376, 0.5535714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16580844490216273, 0.5535714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17051640429601295, 0.6964285714285714, 'x[7] <= 29383.5\ngini = 0.208\nsamples = 17\nvalue = [2, 15]'),
#  Text(0.16933941444755038, 0.6607142857142857, 'x[7] <= 1545.5\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.16816242459908784, 0.625, 'x[6] <= 2834.979\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.16698543475062527, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16933941444755038, 0.5892857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17051640429601295, 0.625, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.17169339414447551, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.166396939826394, 0.7678571428571429, 'x[5] <= 679.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.16521994997793144, 0.7321428571428571, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16757392967485654, 0.7321428571428571, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.16301309401206415, 0.8035714285714286, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17287038399293805, 0.8392857142857143, 'x[5] <= 669.5\ngini = 0.208\nsamples = 34\nvalue = [4, 30]'),
#  Text(0.17169339414447551, 0.8035714285714286, 'x[1] <= 0.175\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.17051640429601295, 0.7678571428571429, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.17287038399293805, 0.7678571428571429, 'x[7] <= 3605.0\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.17169339414447551, 0.7321428571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17404737384140062, 0.7321428571428571, 'x[3] <= 10.91\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.17287038399293805, 0.6964285714285714, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1752243636898632, 0.6964285714285714, 'x[5] <= 659.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17404737384140062, 0.6607142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17640135353832573, 0.6607142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17404737384140062, 0.8035714285714286, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.21423514050316317, 0.9107142857142857, 'x[3] <= 10.381\ngini = 0.464\nsamples = 374\nvalue = [137, 237]'),
#  Text(0.20536633809033397, 0.875, 'x[9] <= 0.5\ngini = 0.291\nsamples = 17\nvalue = [14, 3]'),
#  Text(0.20301235839340886, 0.8392857142857143, 'x[8] <= 92.65\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2018353685449463, 0.8035714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2041893482418714, 0.8035714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20772031778725908, 0.8392857142857143, 'x[8] <= 88.15\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.20654332793879654, 0.8035714285714286, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.20889730763572165, 0.8035714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22310394291599234, 0.875, 'x[1] <= 0.174\ngini = 0.452\nsamples = 357\nvalue = [123, 234]'),
#  Text(0.21242827718110932, 0.8392857142857143, 'x[7] <= 387190.5\ngini = 0.427\nsamples = 291\nvalue = [90, 201]'),
#  Text(0.21125128733264675, 0.8035714285714286, 'x[6] <= 7634.979\ngini = 0.42\nsamples = 287\nvalue = [86, 201]'),
#  Text(0.19961012211269677, 0.7678571428571429, 'x[8] <= 97.15\ngini = 0.444\nsamples = 247\nvalue = [82, 165]'),
#  Text(0.19725614241577166, 0.7321428571428571, 'x[4] <= 1.475\ngini = 0.435\nsamples = 241\nvalue = [77, 164]'),
#  Text(0.1960791525673091, 0.6964285714285714, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.19843313226423423, 0.6964285714285714, 'x[2] <= 702.335\ngini = 0.446\nsamples = 229\nvalue = [77, 152]'),
#  Text(0.18103575106664704, 0.6607142857142857, 'x[2] <= 352.565\ngini = 0.419\nsamples = 191\nvalue = [57, 134]'),
#  Text(0.17287038399293805, 0.625, 'x[9] <= 7.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.17169339414447551, 0.5892857142857143, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.17404737384140062, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18920111814035603, 0.625, 'x[3] <= 11.018\ngini = 0.404\nsamples = 185\nvalue = [52, 133]'),
#  Text(0.17640135353832573, 0.5892857142857143, 'x[3] <= 10.994\ngini = 0.479\nsamples = 63\nvalue = [25, 38]'),
#  Text(0.1752243636898632, 0.5535714285714286, 'x[8] <= 55.75\ngini = 0.444\nsamples = 57\nvalue = [19, 38]'),
#  Text(0.17110489922024422, 0.5178571428571429, 'x[8] <= 25.25\ngini = 0.499\nsamples = 27\nvalue = [14, 13]'),
#  Text(0.16992790937178168, 0.48214285714285715, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.17228188906870678, 0.48214285714285715, 'x[5] <= 719.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.17110489922024422, 0.44642857142857145, 'x[7] <= 9599.0\ngini = 0.444\nsamples = 21\nvalue = [14, 7]'),
#  Text(0.1687509195233191, 0.4107142857142857, 'x[1] <= 0.152\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.16757392967485654, 0.375, 'x[9] <= 7.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.166396939826394, 0.3392857142857143, 'x[1] <= 0.149\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.16521994997793144, 0.30357142857142855, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.16757392967485654, 0.30357142857142855, 'x[7] <= 6341.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.166396939826394, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1687509195233191, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1687509195233191, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16992790937178168, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17345887891716935, 0.4107142857142857, 'x[3] <= 10.477\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.17228188906870678, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1746358687656319, 0.375, 'x[3] <= 10.944\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.17345887891716935, 0.3392857142857143, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.17581285861409446, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17345887891716935, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.17934382815948213, 0.5178571428571429, 'x[6] <= 1769.958\ngini = 0.278\nsamples = 30\nvalue = [5, 25]'),
#  Text(0.176989848462557, 0.48214285714285715, 'x[9] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.17581285861409446, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17816683831101957, 0.44642857142857145, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.18169780785640724, 0.48214285714285715, 'x[1] <= 0.134\ngini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.18052081800794467, 0.44642857142857145, 'x[1] <= 0.131\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17934382815948213, 0.4107142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18169780785640724, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1828747977048698, 0.44642857142857145, 'gini = 0.0\nsamples = 22\nvalue = [0, 22]'),
#  Text(0.1775783433867883, 0.5535714285714286, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.20200088274238634, 0.5892857142857143, 'x[6] <= 6810.042\ngini = 0.345\nsamples = 122\nvalue = [27, 95]'),
#  Text(0.19170222156833897, 0.5535714285714286, 'x[8] <= 1.3\ngini = 0.3\nsamples = 109\nvalue = [20, 89]'),
#  Text(0.18581727232602618, 0.5178571428571429, 'x[5] <= 677.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.18464028247756364, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18699426217448875, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.19758717081065175, 0.5178571428571429, 'x[5] <= 684.5\ngini = 0.282\nsamples = 106\nvalue = [18, 88]'),
#  Text(0.18934824187141386, 0.48214285714285715, 'x[1] <= 0.146\ngini = 0.414\nsamples = 41\nvalue = [12, 29]'),
#  Text(0.18522877740179491, 0.44642857142857145, 'x[9] <= 3.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.18405178755333235, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.18640576725025745, 0.4107142857142857, 'x[8] <= 46.1\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.18522877740179491, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.18758275709872002, 0.375, 'x[4] <= 20.35\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.18640576725025745, 0.3392857142857143, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.1887597469471826, 0.3392857142857143, 'x[4] <= 22.035\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.18758275709872002, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18993673679564513, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1934677063410328, 0.44642857142857145, 'x[2] <= 462.79\ngini = 0.328\nsamples = 29\nvalue = [6, 23]'),
#  Text(0.19229071649257026, 0.4107142857142857, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.19464469618949537, 0.4107142857142857, 'x[4] <= 12.56\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(0.19229071649257026, 0.375, 'x[5] <= 664.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.1911137266441077, 0.3392857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1934677063410328, 0.3392857142857143, 'x[2] <= 612.575\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.19229071649257026, 0.30357142857142855, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19464469618949537, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.19699867588642048, 0.375, 'x[9] <= 5.0\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.1958216860379579, 0.3392857142857143, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.19817566573488304, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20582609974988966, 0.48214285714285715, 'x[2] <= 497.52\ngini = 0.168\nsamples = 65\nvalue = [6, 59]'),
#  Text(0.20288362512873326, 0.44642857142857145, 'x[8] <= 55.05\ngini = 0.311\nsamples = 26\nvalue = [5, 21]'),
#  Text(0.20170663528027072, 0.4107142857142857, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.20406061497719583, 0.4107142857142857, 'x[5] <= 702.0\ngini = 0.473\nsamples = 13\nvalue = [5, 8]'),
#  Text(0.20170663528027072, 0.375, 'x[7] <= 10804.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.20052964543180815, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20288362512873326, 0.3392857142857143, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.20641459467412093, 0.375, 'x[4] <= 24.265\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.20523760482565837, 0.3392857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2075915845225835, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.20876857437104604, 0.44642857142857145, 'x[3] <= 12.283\ngini = 0.05\nsamples = 39\nvalue = [1, 38]'),
#  Text(0.2075915845225835, 0.4107142857142857, 'gini = 0.0\nsamples = 34\nvalue = [0, 34]'),
#  Text(0.2099455642195086, 0.4107142857142857, 'x[3] <= 12.308\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.20876857437104604, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21112255406797117, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.21229954391643371, 0.5535714285714286, 'x[8] <= 84.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.21112255406797117, 0.5178571428571429, 'x[6] <= 6945.021\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.2099455642195086, 0.48214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.21229954391643371, 0.48214285714285715, 'x[6] <= 7590.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.21112255406797117, 0.44642857142857145, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.21347653376489628, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.21347653376489628, 0.5178571428571429, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2158305134618214, 0.6607142857142857, 'x[1] <= 0.127\ngini = 0.499\nsamples = 38\nvalue = [20, 18]'),
#  Text(0.21347653376489628, 0.625, 'x[3] <= 12.396\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.21229954391643371, 0.5892857142857143, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.21465352361335882, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2181844931587465, 0.625, 'x[2] <= 716.32\ngini = 0.477\nsamples = 28\nvalue = [11, 17]'),
#  Text(0.21700750331028396, 0.5892857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.21936148300720906, 0.5892857142857143, 'x[4] <= 12.04\ngini = 0.435\nsamples = 25\nvalue = [8, 17]'),
#  Text(0.21700750331028396, 0.5535714285714286, 'x[6] <= 3150.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.2158305134618214, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
# ...
#  Text(0.3773723701633073, 0.44642857142857145, 'x[6] <= 1979.979\ngini = 0.185\nsamples = 87\nvalue = [9, 78]'),
#  Text(0.37501839046638225, 0.4107142857142857, 'x[4] <= 12.76\ngini = 0.137\nsamples = 81\nvalue = [6, 75]'),
#  Text(0.37384140061791965, 0.375, 'gini = 0.0\nsamples = 39\nvalue = [0, 39]'),
#  Text(0.3761953803148448, 0.375, 'x[4] <= 13.395\ngini = 0.245\nsamples = 42\nvalue = [6, 36]'),
#  Text(0.37384140061791965, 0.3392857142857143, 'x[3] <= 10.765\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3726644107694571, 0.30357142857142855, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37501839046638225, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3785493600117699, 0.3392857142857143, 'x[2] <= 465.69\ngini = 0.184\nsamples = 39\nvalue = [4, 35]'),
#  Text(0.3773723701633073, 0.30357142857142855, 'x[8] <= 90.05\ngini = 0.145\nsamples = 38\nvalue = [3, 35]'),
#  Text(0.3761953803148448, 0.26785714285714285, 'x[2] <= 280.375\ngini = 0.102\nsamples = 37\nvalue = [2, 35]'),
#  Text(0.37501839046638225, 0.23214285714285715, 'gini = 0.0\nsamples = 29\nvalue = [0, 29]'),
#  Text(0.3773723701633073, 0.23214285714285715, 'x[2] <= 342.08\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.3761953803148448, 0.19642857142857142, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3785493600117699, 0.19642857142857142, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3785493600117699, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37972634986023246, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37972634986023246, 0.4107142857142857, 'x[7] <= 11194.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.3785493600117699, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.380903339708695, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.38781815506841255, 0.44642857142857145, 'x[2] <= 51.12\ngini = 0.048\nsamples = 204\nvalue = [5, 199]'),
#  Text(0.3844343092540827, 0.4107142857142857, 'x[1] <= 0.137\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.38325731940562013, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3856112991025452, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3912020008827424, 0.4107142857142857, 'x[1] <= 0.157\ngini = 0.039\nsamples = 202\nvalue = [4, 198]'),
#  Text(0.38796527879947035, 0.375, 'x[8] <= 93.95\ngini = 0.03\nsamples = 196\nvalue = [3, 193]'),
#  Text(0.38502280417831397, 0.3392857142857143, 'x[2] <= 85.12\ngini = 0.021\nsamples = 189\nvalue = [2, 187]'),
#  Text(0.38266882448138884, 0.30357142857142855, 'x[2] <= 83.65\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.3814918346329263, 0.26785714285714285, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.38384581432985143, 0.26785714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38737678387523905, 0.30357142857142855, 'x[3] <= 11.384\ngini = 0.011\nsamples = 175\nvalue = [1, 174]'),
#  Text(0.3861997940267765, 0.26785714285714285, 'gini = 0.0\nsamples = 158\nvalue = [0, 158]'),
#  Text(0.38855377372370165, 0.26785714285714285, 'x[3] <= 11.399\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(0.38737678387523905, 0.23214285714285715, 'x[4] <= 12.22\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3861997940267765, 0.19642857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38855377372370165, 0.19642857142857142, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3897307635721642, 0.23214285714285715, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.3909077534206267, 0.3392857142857143, 'x[7] <= 16916.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.3897307635721642, 0.30357142857142855, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.3920847432690893, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3944387229660144, 0.375, 'x[6] <= 2699.979\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.39326173311755186, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.395615712814477, 0.3392857142857143, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.3970869501250552, 0.48214285714285715, 'x[1] <= 0.132\ngini = 0.293\nsamples = 28\nvalue = [5, 23]'),
#  Text(0.39473297042813005, 0.44642857142857145, 'x[3] <= 11.212\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.3935559805796675, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3959099602765926, 0.4107142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.39944092982198026, 0.44642857142857145, 'x[4] <= 11.04\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.3982639399735177, 0.4107142857142857, 'x[1] <= 0.146\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.3970869501250552, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.39944092982198026, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.40061791967044286, 0.4107142857142857, 'gini = 0.0\nsamples = 18\nvalue = [0, 18]'),
#  Text(0.38360673826688246, 0.625, 'x[7] <= 10973.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.38242974841841987, 0.5892857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.384783728115345, 0.5892857142857143, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.43248859791084304, 0.6607142857142857, 'x[3] <= 9.657\ngini = 0.292\nsamples = 208\nvalue = [37, 171]'),
#  Text(0.42526114462262765, 0.625, 'x[3] <= 9.561\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.42408415477416506, 0.5892857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4264381344710902, 0.5892857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.43971605119905843, 0.625, 'x[3] <= 10.597\ngini = 0.278\nsamples = 204\nvalue = [34, 170]'),
#  Text(0.4287921141680153, 0.5892857142857143, 'x[4] <= 22.115\ngini = 0.362\nsamples = 101\nvalue = [24, 77]'),
#  Text(0.4181256436663234, 0.5535714285714286, 'x[3] <= 10.477\ngini = 0.43\nsamples = 64\nvalue = [20, 44]'),
#  Text(0.41209357069295277, 0.5178571428571429, 'x[6] <= 2790.0\ngini = 0.351\nsamples = 44\nvalue = [10, 34]'),
#  Text(0.4070913638369869, 0.48214285714285715, 'x[7] <= 3521.5\ngini = 0.251\nsamples = 34\nvalue = [5, 29]'),
#  Text(0.40414888921583053, 0.44642857142857145, 'x[8] <= 41.55\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.40297189936736794, 0.4107142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.40532587906429307, 0.4107142857142857, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4100338384581433, 0.44642857142857145, 'x[4] <= 21.635\ngini = 0.137\nsamples = 27\nvalue = [2, 25]'),
#  Text(0.4076798587612182, 0.4107142857142857, 'x[5] <= 699.5\ngini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(0.4065028689127556, 0.375, 'gini = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(0.40885684860968075, 0.375, 'x[6] <= 2071.021\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.4076798587612182, 0.3392857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4100338384581433, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4123878181550684, 0.4107142857142857, 'x[9] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4112108283066059, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41356480800353096, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.41709577754891863, 0.48214285714285715, 'x[6] <= 3332.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(0.4159187877004561, 0.44642857142857145, 'x[1] <= 0.122\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.4147417978519935, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.41709577754891863, 0.4107142857142857, 'x[5] <= 664.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4159187877004561, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4182727673973812, 0.375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4182727673973812, 0.44642857142857145, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.424157716639694, 0.5178571428571429, 'x[2] <= 203.09\ngini = 0.5\nsamples = 20\nvalue = [10, 10]'),
#  Text(0.42180373694276885, 0.48214285714285715, 'x[8] <= 31.25\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.4206267470943063, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.42298072679123144, 0.44642857142857145, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.4265116963366191, 0.48214285714285715, 'x[6] <= 1365.021\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.4253347064881565, 0.44642857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.42768868618508166, 0.44642857142857145, 'x[1] <= 0.116\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.4265116963366191, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4288656760335442, 0.4107142857142857, 'x[2] <= 340.795\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.42768868618508166, 0.375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.4300426658820068, 0.375, 'x[7] <= 15022.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4288656760335442, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.43121965573046933, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4394585846697072, 0.5535714285714286, 'x[4] <= 24.97\ngini = 0.193\nsamples = 37\nvalue = [4, 33]'),
#  Text(0.4382815948212447, 0.5178571428571429, 'x[7] <= 20787.5\ngini = 0.153\nsamples = 36\nvalue = [3, 33]'),
#  Text(0.4371046049727821, 0.48214285714285715, 'x[6] <= 3393.542\ngini = 0.108\nsamples = 35\nvalue = [2, 33]'),
#  Text(0.434750625275857, 0.44642857142857145, 'x[5] <= 664.5\ngini = 0.059\nsamples = 33\nvalue = [1, 32]'),
#  Text(0.43357363542739447, 0.4107142857142857, 'x[3] <= 10.4\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.43239664557893187, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.434750625275857, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.43592761512431955, 0.4107142857142857, 'gini = 0.0\nsamples = 30\nvalue = [0, 30]'),
#  Text(0.4394585846697072, 0.44642857142857145, 'x[5] <= 694.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4382815948212447, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.44063557451816976, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4394585846697072, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44063557451816976, 0.5178571428571429, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45063998823010154, 0.5892857142857143, 'x[7] <= 13584.5\ngini = 0.175\nsamples = 103\nvalue = [10, 93]'),
#  Text(0.4476975136089451, 0.5535714285714286, 'x[2] <= 535.995\ngini = 0.287\nsamples = 46\nvalue = [8, 38]'),
#  Text(0.44652052376048257, 0.5178571428571429, 'x[7] <= 13544.5\ngini = 0.206\nsamples = 43\nvalue = [5, 38]'),
#  Text(0.44534353391202003, 0.48214285714285715, 'x[5] <= 684.5\ngini = 0.172\nsamples = 42\nvalue = [4, 38]'),
#  Text(0.44416654406355743, 0.44642857142857145, 'x[6] <= 3329.979\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.4429895542150949, 0.4107142857142857, 'x[4] <= 21.34\ngini = 0.255\nsamples = 20\nvalue = [3, 17]'),
#  Text(0.44181256436663235, 0.375, 'x[1] <= 0.142\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.44063557451816976, 0.3392857142857143, 'x[3] <= 11.018\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.4394585846697072, 0.30357142857142855, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.44181256436663235, 0.30357142857142855, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4429895542150949, 0.3392857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.44416654406355743, 0.375, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.44534353391202003, 0.4107142857142857, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.44652052376048257, 0.44642857142857145, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(0.4476975136089451, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4488745034574077, 0.5178571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4535824628512579, 0.5535714285714286, 'x[7] <= 55859.0\ngini = 0.068\nsamples = 57\nvalue = [2, 55]'),
#  Text(0.4512284831543328, 0.5178571428571429, 'x[5] <= 669.5\ngini = 0.036\nsamples = 55\nvalue = [1, 54]'),
#  Text(0.45005149330587024, 0.48214285714285715, 'x[6] <= 3330.0\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.4488745034574077, 0.44642857142857145, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.4512284831543328, 0.44642857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4524054730027954, 0.48214285714285715, 'gini = 0.0\nsamples = 48\nvalue = [0, 48]'),
#  Text(0.455936442548183, 0.5178571428571429, 'x[5] <= 694.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.45475945269972046, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4571134323966456, 0.48214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5305074849198176, 0.6964285714285714, 'x[6] <= 4440.521\ngini = 0.284\nsamples = 1033\nvalue = [177, 856]'),
#  Text(0.4955219214359276, 0.6607142857142857, 'x[8] <= 73.65\ngini = 0.35\nsamples = 345\nvalue = [78, 267]'),
#  Text(0.48302559952920404, 0.625, 'x[6] <= 4439.979\ngini = 0.285\nsamples = 227\nvalue = [39, 188]'),
#  Text(0.47598205090481094, 0.5892857142857143, 'x[3] <= 11.039\ngini = 0.262\nsamples = 219\nvalue = [34, 185]'),
#  Text(0.4654259232014124, 0.5535714285714286, 'x[2] <= 538.13\ngini = 0.342\nsamples = 137\nvalue = [30, 107]'),
#  Text(0.4642489333529498, 0.5178571428571429, 'x[3] <= 10.525\ngini = 0.291\nsamples = 130\nvalue = [23, 107]'),
#  Text(0.45946741209357067, 0.48214285714285715, 'x[3] <= 10.484\ngini = 0.439\nsamples = 40\nvalue = [13, 27]'),
#  Text(0.45829042224510813, 0.44642857142857145, 'x[1] <= 0.117\ngini = 0.394\nsamples = 37\nvalue = [10, 27]'),
#  Text(0.45534794762395175, 0.4107142857142857, 'x[6] <= 3900.979\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.4529939679270266, 0.375, 'x[7] <= 1715.0\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.4518169780785641, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45417095777548916, 0.3392857142857143, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.45770192732087683, 0.375, 'x[2] <= 311.815\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.4565249374724143, 0.3392857142857143, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.45887891716933943, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4612328968662645, 0.4107142857142857, 'x[6] <= 3554.5\ngini = 0.269\nsamples = 25\nvalue = [4, 21]'),
#  Text(0.46005590701780197, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4624098867147271, 0.375, 'x[8] <= 72.1\ngini = 0.219\nsamples = 24\nvalue = [3, 21]'),
#  Text(0.4612328968662645, 0.3392857142857143, 'x[4] <= 11.56\ngini = 0.159\nsamples = 23\nvalue = [2, 21]'),
#  Text(0.46005590701780197, 0.30357142857142855, 'x[2] <= 204.395\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.45887891716933943, 0.26785714285714285, 'x[8] <= 63.3\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.45770192732087683, 0.23214285714285715, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.46005590701780197, 0.23214285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4612328968662645, 0.26785714285714285, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.4624098867147271, 0.30357142857142855, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(0.46358687656318964, 0.3392857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.46064440194203327, 0.44642857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.46903045461232895, 0.48214285714285715, 'x[2] <= 58.925\ngini = 0.198\nsamples = 90\nvalue = [10, 80]'),
#  Text(0.4647638664116522, 0.44642857142857145, 'x[2] <= 49.115\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  ...]

# %%
#Lets take a look
#this also takes a minute . . . or two
text_representation = tree.export_text(dTree)
print(text_representation)
# Out:
# |--- feature_0 <= 0.50
# |   |--- feature_2 <= 349.93
# |   |   |--- feature_9 <= 6.50
# |   |   |   |--- feature_1 <= 0.08
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  0.08
# |   |   |   |   |--- feature_8 <= 50.95
# |   |   |   |   |   |--- feature_8 <= 47.35
# |   |   |   |   |   |   |--- feature_3 <= 9.82
# |   |   |   |   |   |   |   |--- feature_2 <= 78.13
# |   |   |   |   |   |   |   |   |--- feature_8 <= 12.95
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 4.43
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  4.43
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.19
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  12.95
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  78.13
# |   |   |   |   |   |   |   |   |--- feature_8 <= 19.65
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.88
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.88
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 14.86
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  14.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  19.65
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3285.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3285.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  9.82
# |   |   |   |   |   |   |   |--- feature_3 <= 10.44
# |   |   |   |   |   |   |   |   |--- feature_5 <= 734.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 7680.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 153.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  153.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  7680.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 674.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  674.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_5 >  734.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  10.44
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.29
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.29
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 6.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  6.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  14.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |--- feature_8 >  47.35
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  50.95
# |   |   |   |   |   |--- feature_6 <= 5342.00
# |   |   |   |   |   |   |--- feature_7 <= 7884.00
# |   |   |   |   |   |   |   |--- feature_5 <= 712.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 7535.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 20.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  20.94
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 669.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  669.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_7 >  7535.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.12
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_5 >  712.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_7 >  7884.00
# |   |   |   |   |   |   |   |--- feature_9 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.38
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 83.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 82.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  82.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  83.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 709.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  709.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.38
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.40
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2459.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  2459.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.40
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 95.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  95.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_9 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 669.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  669.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 21280.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  21280.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 184.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  184.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  5342.00
# |   |   |   |   |   |   |--- feature_6 <= 5579.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_6 >  5579.50
# |   |   |   |   |   |   |   |--- feature_8 <= 57.15
# |   |   |   |   |   |   |   |   |--- feature_5 <= 647.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_5 >  647.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  57.15
# |   |   |   |   |   |   |   |   |--- feature_8 <= 80.25
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 137.93
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 69.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  69.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  137.93
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 60.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  60.30
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  80.25
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 121.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  121.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 17.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  17.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |--- feature_9 >  6.50
# |   |   |   |--- feature_1 <= 0.16
# |   |   |   |   |--- feature_1 <= 0.15
# |   |   |   |   |   |--- feature_6 <= 6373.98
# |   |   |   |   |   |   |--- feature_6 <= 1125.02
# |   |   |   |   |   |   |   |--- feature_8 <= 21.55
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.91
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.91
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_8 >  21.55
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_6 >  1125.02
# |   |   |   |   |   |   |   |--- feature_2 <= 259.77
# |   |   |   |   |   |   |   |   |--- feature_2 <= 171.59
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 38.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  38.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 29.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  29.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_2 >  171.59
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 694.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 36.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  36.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  694.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 18114.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  18114.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_2 >  259.77
# |   |   |   |   |   |   |   |   |--- feature_7 <= 29383.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1545.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 2834.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  2834.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1545.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  29383.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  6373.98
# |   |   |   |   |   |   |--- feature_5 <= 679.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_5 >  679.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  0.15
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.16
# |   |   |   |   |--- feature_5 <= 669.50
# |   |   |   |   |   |--- feature_1 <= 0.17
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_1 >  0.17
# |   |   |   |   |   |   |--- feature_7 <= 3605.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  3605.00
# |   |   |   |   |   |   |   |--- feature_3 <= 10.91
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  10.91
# |   |   |   |   |   |   |   |   |--- feature_5 <= 659.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  659.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_5 >  669.50
# |   |   |   |   |   |--- class: 1
# |   |--- feature_2 >  349.93
# |   |   |--- feature_3 <= 10.38
# |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |--- feature_8 <= 92.65
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_8 >  92.65
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |--- feature_8 <= 88.15
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_8 >  88.15
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_3 >  10.38
# |   |   |   |--- feature_1 <= 0.17
# |   |   |   |   |--- feature_7 <= 387190.50
# |   |   |   |   |   |--- feature_6 <= 7634.98
# |   |   |   |   |   |   |--- feature_8 <= 97.15
# |   |   |   |   |   |   |   |--- feature_4 <= 1.48
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_4 >  1.48
# |   |   |   |   |   |   |   |   |--- feature_2 <= 702.33
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 352.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  352.56
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_2 >  702.33
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 12.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  12.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 716.32
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  716.32
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- feature_8 >  97.15
# |   |   |   |   |   |   |   |--- feature_4 <= 19.84
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  19.84
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_6 >  7634.98
# |   |   |   |   |   |   |--- feature_4 <= 27.06
# |   |   |   |   |   |   |   |--- feature_9 <= 10.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 12.65
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  12.65
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 12.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  12.81
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_9 >  10.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_4 >  27.06
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_7 >  387190.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_1 >  0.17
# |   |   |   |   |--- feature_7 <= 88748.00
# |   |   |   |   |   |--- feature_7 <= 7358.00
# |   |   |   |   |   |   |--- feature_8 <= 27.55
# |   |   |   |   |   |   |   |--- feature_7 <= 4517.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 657.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_5 >  657.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 641.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  641.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  4517.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  27.55
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  7358.00
# |   |   |   |   |   |   |--- feature_2 <= 360.48
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  360.48
# |   |   |   |   |   |   |   |--- feature_1 <= 0.21
# |   |   |   |   |   |   |   |   |--- feature_8 <= 41.20
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  41.20
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.60
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 6615.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  6615.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_1 >  0.21
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_7 >  88748.00
# |   |   |   |   |   |--- feature_3 <= 12.43
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  12.43
# |   |   |   |   |   |   |--- feature_5 <= 664.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  664.50
# |   |   |   |   |   |   |   |--- class: 1
# |--- feature_0 >  0.50
# |   |--- feature_1 <= 0.09
# |   |   |--- feature_7 <= 109752.00
# |   |   |   |--- feature_3 <= 9.26
# |   |   |   |   |--- feature_2 <= 122.53
# |   |   |   |   |   |--- feature_7 <= 1680.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_7 >  1680.50
# |   |   |   |   |   |   |--- feature_7 <= 2265.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_7 >  2265.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  122.53
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  9.26
# |   |   |   |   |--- feature_2 <= 562.22
# |   |   |   |   |   |--- feature_5 <= 749.50
# |   |   |   |   |   |   |--- feature_8 <= 75.70
# |   |   |   |   |   |   |   |--- feature_6 <= 1215.04
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_6 >  1215.04
# |   |   |   |   |   |   |   |   |--- feature_6 <= 8011.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 15.86
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 15.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  15.63
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  15.86
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_6 >  8011.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 8085.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  8085.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  75.70
# |   |   |   |   |   |   |   |--- feature_3 <= 11.77
# |   |   |   |   |   |   |   |   |--- feature_6 <= 3974.52
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_6 >  3974.52
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  11.77
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_5 >  749.50
# |   |   |   |   |   |   |--- feature_9 <= 3.50
# |   |   |   |   |   |   |   |--- feature_5 <= 819.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 14054.98
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 17550.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  17550.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 17590.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  17590.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- feature_6 >  14054.98
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 769.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  769.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_5 >  819.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.08
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.08
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_9 >  3.50
# |   |   |   |   |   |   |   |--- feature_6 <= 5429.52
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.05
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.05
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_6 >  5429.52
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  562.22
# |   |   |   |   |   |--- feature_6 <= 7259.98
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  7259.98
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_7 >  109752.00
# |   |   |   |--- class: 0
# |   |--- feature_1 >  0.09
# |   |   |--- feature_9 <= 2.50
# |   |   |   |--- feature_1 <= 0.16
# |   |   |   |   |--- feature_5 <= 704.50
# |   |   |   |   |   |--- feature_2 <= 32.72
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  32.72
# |   |   |   |   |   |   |--- feature_3 <= 9.45
# |   |   |   |   |   |   |   |--- feature_6 <= 3105.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 5028.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8.39
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  8.39
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  5028.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_6 >  3105.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  9.45
# |   |   |   |   |   |   |   |--- feature_6 <= 3529.02
# |   |   |   |   |   |   |   |   |--- feature_4 <= 18.35
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 699.39
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 9.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  9.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  699.39
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 10973.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  10973.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_4 >  18.35
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.66
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.56
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.66
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- feature_6 >  3529.02
# |   |   |   |   |   |   |   |   |--- feature_6 <= 4440.52
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 73.65
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 4439.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  4439.98
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  73.65
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 27137.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  27137.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_6 >  4440.52
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 98.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  98.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- feature_5 >  704.50
# |   |   |   |   |   |--- feature_2 <= 837.16
# |   |   |   |   |   |   |--- feature_8 <= 90.55
# |   |   |   |   |   |   |   |--- feature_7 <= 136634.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.47
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 335.72
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 52.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  52.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  335.72
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.47
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 14549.96
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 24.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  24.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  14549.96
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  136634.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_8 >  90.55
# |   |   |   |   |   |   |   |--- feature_1 <= 0.10
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_1 >  0.10
# |   |   |   |   |   |   |   |   |--- feature_7 <= 17902.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3240.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  3240.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_7 >  17902.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 9.26
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  9.26
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_2 >  837.16
# |   |   |   |   |   |   |--- feature_6 <= 3120.54
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_6 >  3120.54
# |   |   |   |   |   |   |   |--- feature_2 <= 854.15
# |   |   |   |   |   |   |   |   |--- feature_2 <= 844.02
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  844.02
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 12.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  12.11
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  854.15
# |   |   |   |   |   |   |   |   |--- feature_7 <= 72156.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  72156.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_1 >  0.16
# |   |   |   |   |--- feature_5 <= 714.50
# |   |   |   |   |   |--- feature_1 <= 0.16
# |   |   |   |   |   |   |--- feature_1 <= 0.16
# |   |   |   |   |   |   |   |--- feature_3 <= 10.73
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  10.73
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_1 >  0.16
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.16
# |   |   |   |   |   |   |--- feature_3 <= 11.90
# |   |   |   |   |   |   |   |--- feature_1 <= 0.20
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.01
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3225.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  3225.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 51.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  51.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.01
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 34914.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 24.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  24.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  34914.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_1 >  0.20
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.02
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.02
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 17.90
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  17.90
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  11.90
# |   |   |   |   |   |   |   |--- feature_6 <= 6779.98
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.19
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 77.85
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  77.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 92.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  92.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.19
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_6 >  6779.98
# |   |   |   |   |   |   |   |   |--- feature_6 <= 9135.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_6 >  9135.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_5 >  714.50
# |   |   |   |   |   |--- feature_6 <= 7004.98
# |   |   |   |   |   |   |--- feature_5 <= 752.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  752.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_6 >  7004.98
# |   |   |   |   |   |   |--- class: 1
# |   |   |--- feature_9 >  2.50
# |   |   |   |--- feature_8 <= 56.05
# |   |   |   |   |--- feature_3 <= 11.31
# |   |   |   |   |   |--- feature_1 <= 0.14
# |   |   |   |   |   |   |--- feature_4 <= 24.48
# |   |   |   |   |   |   |   |--- feature_6 <= 1544.98
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1004.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  1004.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 677.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  677.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_6 >  1544.98
# |   |   |   |   |   |   |   |   |--- feature_7 <= 39197.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.30
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 55.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  55.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.30
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  39197.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 55064.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  55064.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  24.48
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_1 >  0.14
# |   |   |   |   |   |   |--- feature_1 <= 0.15
# |   |   |   |   |   |   |   |--- feature_2 <= 175.47
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  175.47
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_1 >  0.15
# |   |   |   |   |   |   |   |--- feature_7 <= 7766.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 4777.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2074.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.72
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  2074.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  4777.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_7 >  7766.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  11.31
# |   |   |   |   |   |--- feature_8 <= 39.55
# |   |   |   |   |   |   |--- feature_4 <= 3.55
# |   |   |   |   |   |   |   |--- feature_3 <= 11.80
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.38
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.38
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 290.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  290.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  11.80
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_4 >  3.55
# |   |   |   |   |   |   |   |--- feature_1 <= 0.10
# |   |   |   |   |   |   |   |   |--- feature_8 <= 27.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_8 >  27.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.60
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_1 >  0.10
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_8 >  39.55
# |   |   |   |   |   |   |--- feature_5 <= 704.50
# |   |   |   |   |   |   |   |--- feature_7 <= 13867.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_7 >  13867.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 11.55
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  11.55
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_5 >  704.50
# |   |   |   |   |   |   |   |--- feature_8 <= 40.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  40.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 42.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 12491.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  12491.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_8 >  42.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_8 >  56.05
# |   |   |   |   |--- feature_1 <= 0.17
# |   |   |   |   |   |--- feature_3 <= 11.33
# |   |   |   |   |   |   |--- feature_9 <= 5.50
# |   |   |   |   |   |   |   |--- feature_4 <= 11.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 10027.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  10027.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.11
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 46.02
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  46.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 11.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  11.21
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_4 >  11.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 10.70
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.63
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 23.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  23.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.63
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 3464.96
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  3464.96
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  10.70
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_9 >  5.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  11.33
# |   |   |   |   |   |   |--- feature_3 <= 11.50
# |   |   |   |   |   |   |   |--- feature_2 <= 279.04
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  279.04
# |   |   |   |   |   |   |   |   |--- feature_7 <= 40638.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 94.55
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 11.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  11.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  94.55
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_7 >  40638.00
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  11.50
# |   |   |   |   |   |   |   |--- feature_2 <= 743.45
# |   |   |   |   |   |   |   |   |--- feature_7 <= 87398.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_7 >  87398.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 16.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  16.93
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  743.45
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_1 >  0.17
# |   |   |   |   |   |--- feature_6 <= 5306.00
# |   |   |   |   |   |   |--- feature_6 <= 1675.54
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_6 >  1675.54
# |   |   |   |   |   |   |   |--- feature_8 <= 79.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 812.65
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  812.65
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_8 >  79.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_6 >  5306.00
# |   |   |   |   |   |   |--- class: 1

# %%
# another way to visualize the tree
# this tree has lots of branches
fn=['credit.policy','int.rate','installment','log.annual.inc','dti','fico','days.with.cr.line','revol.bal','revol.util','inq.last.6mths']
cn=['0','1']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (14,14), dpi=300)
tree.plot_tree(dTree,
               feature_names = fn,
               class_names=cn,
               filled = True);fig.savefig('imagename.png')
# Out:
# Error in callback <function flush_figures at 0x7eb3614343a0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.10/dist-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2340                 )
#    2341                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2342                     self.figure.draw(renderer)
#    2343
#    2344             if bbox_inches:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      93     @wraps(draw)
#      94     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95         result = draw(artist, renderer, *args, **kwargs)
#      96         if renderer._rasterizing:
#      97             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3138
#    3139             self.patch.draw(renderer)
# -> 3140             mimage._draw_list_compositing_images(
#    3141                 renderer, self, artists, self.suppressComposite)
#    3142
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3062             _draw_rasterized(self.figure, artists_rasterized, renderer)
#    3063
# -> 3064         mimage._draw_list_compositing_images(
#    3065             renderer, self, artists, self.figure.suppressComposite)
#    3066
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      70                 renderer.start_filter()
#      71
# ---> 72             return draw(artist, renderer)
#      73         finally:
#      74             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/text.py in draw(self, renderer)
#    2030             if self.arrow_patch.figure is None and self.figure is not None:
#    2031                 self.arrow_patch.figure = self.figure
# -> 2032             self.arrow_patch.draw(renderer)
#    2033         # Draw text, including FancyBboxPatch, after FancyArrowPatch.
#    2034         # Otherwise, a wedge arrowstyle can land partly on top of the Bbox.
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      37             renderer._rasterizing = False
#      38
# ---> 39         return draw(artist, renderer, *args, **kwargs)
#      40
#      41     draw_wrapper._supports_rasterization = False
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in draw(self, renderer)
#    4350         # take a renderer argument, but get_path should be adapted too.
#    4351         self._dpi_cor = renderer.points_to_pixels(1.)
# -> 4352         path, fillable = self._get_path_in_displaycoord()
#    4353
#    4354         if not np.iterable(fillable):
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in _get_path_in_displaycoord(self)
#    4325             posB = self._convert_xy_units(self._posA_posB[1])
#    4326             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4327             _path = self.get_connectionstyle()(posA, posB,
#    4328                                                patchA=self.patchA,
#    4329                                                patchB=self.patchB,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2730                 self._in_patch(patchB) if patchB else None,
#    2731             )
# -> 2732             path = self._clip(
#    2733                 path,
#    2734                 inside_circle(*path.vertices[0], shrinkA) if shrinkA else None,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/patches.py in _clip(self, path, in_start, in_stop)
#    2708             if in_start:
#    2709                 try:
# -> 2710                     _, path = split_path_inout(path, in_start)
#    2711                 except ValueError:
#    2712                     pass
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     368
#     369     bp = bezier_path.reshape((-1, 2))
# --> 370     left, right = split_bezier_intersecting_with_closedpath(
#     371         bp, inside, tolerance)
#     372     if len(left) == 2:
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     331     bezier_point_at_t = bz.point_at_t
#     332
# --> 333     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     334         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     335
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     167         # calculate the middle point
#     168         middle_t = 0.5 * (t0 + t1)
# --> 169         middle = bezier_point_at_t(middle_t)
#     170         middle_inside = inside_closedpath(middle)
#     171
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in point_at_t(self, t)
#     220         Evaluate the curve at a single point, returning a tuple of *d* floats.
#     221         """
# --> 222         return tuple(self(t))
#     223
#     224     @property
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/bezier.py in __call__(self, t)
#     214         t = np.asarray(t)
#     215         return (np.power.outer(1 - t, self._orders[::-1])
# --> 216                 * np.power.outer(t, self._orders)) @ self._px
#     217
#     218     def point_at_t(self, t):
#
# KeyboardInterrupt:

# %% [markdown]
# ## 7. Predictions and Evaluation of Decision Tree
# **Create predictions from the test set and create a confusion matrix and classfication report to evaluate our model.**

# %%
# create the predictions from the test set
predictions = dTree.predict(X_test)

# %%
# import the necessary libraries from sklearn.metrics
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ## Evaluation using a confusion matrix
# A confusion matrix is a great way to evaluate a classifcation model.<br>

# %%
#create the confusion matrix
cf_matrix = confusion_matrix(y_test,predictions)
print(cf_matrix)
# Can we look at this in a better, more intuitive way? What does this mean?
# Out:
# [[  90  353]
#  [ 396 2035]]

# %%
# use seaborn to make the confusion matrix more intuitive
# True Positives are Predicted Yes, Actual Yes or 2019
# True Negatives are Predicted No, Actual No or 93
# False Positives are Predicted Yes, Actual No or 350
# False Negatives are Predicted No, Actual Yes or 412
# Total = 2019+93+350+412 = 2874
# Remember this is the test set - 30% of total records

xlabels = ['Predicted: No','Predicted: Yes']
ylabels = ['Actual: No', 'Actual: Yes']
sns.heatmap(cf_matrix,xticklabels=xlabels,yticklabels=ylabels,annot=True,fmt='g',cmap='Blues')
# Out:
# <Axes: >

# %%
# Let's see the percentages in each column, this will help us understand the classification report
xlabels = ['Predicted: No','Predicted: Yes']
ylabels = ['Actual: No', 'Actual: Yes']
sns.heatmap(cf_matrix/np.sum(cf_matrix),xticklabels=xlabels,yticklabels=ylabels,annot=True,fmt='.2%',cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ## Here is the classification report built from the confusion matrix<br>
#
# Learn more about the numbers here and see question below that you need to answer:  <a href="https://www.analyticsvidhya.com/blog/2020/04/confusion-matrix-machine-learning/">Explaining the Confusion Matrix</a>

# %%
#print the classification report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.19      0.20      0.19       443
#            1       0.85      0.84      0.84      2431
#
#     accuracy                           0.74      2874
#    macro avg       0.52      0.52      0.52      2874
# weighted avg       0.75      0.74      0.74      2874

# %% [markdown]
# ## Question 5:  Using the link provided above, explain the classification report and confusion matrix charts that have been built. Is the F1 score the best measure of accuracy?
# The classification report gives us metrics such as precision, recall, F1-score, and support. The confusion matrix gives us a visual representation of a  classification model. The F-1 score is useful because is evaluated the performance of the borrowers paying their loans or not.

# %% [markdown]
# ## 8. Training the Random Forest model
#
# Now its time to train our Random Forest Model which will built lots of decision trees and average the results.  This is called an ensemble model and is usually a great model for data that has a target variable (supervised) and can benefit from decision tree analysis!

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=300)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=300)

# %% [markdown]
# ## Predictions and Evaluation
#
# Let's predict off the y_test values and evaluate our model.
#
# ** Predict the class of fully.paid for the X_test data.**

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(classification_report(y_test,rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.39      0.02      0.04       443
#            1       0.85      0.99      0.92      2431
#
#     accuracy                           0.84      2874
#    macro avg       0.62      0.51      0.48      2874
# weighted avg       0.78      0.84      0.78      2874

# %%
print(confusion_matrix(y_test,rfc_pred))
# Out:
# [[   9  434]
#  [  14 2417]]

# %% [markdown]
# ## Question 6:  Which model perfomed better?  Single Decision Tree or Random Forest? How can you tell?
# The single decision tree performed better beacuse gave us more precision on the data. It did that and had an F-1 score for both classes.It gave us better counts of true positive, true negatives, false positives, and false negatives.

# %% [markdown]
# # The end!
